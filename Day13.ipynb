# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek-383/Data-science---45-days/blob/main/Day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**
# 1. Reading data
# 2. Cleaning data
# 3. Analyzing data
# 4. Manipulating data

# %%
import pandas as pd
# import pandas
# from pandas import Series, DataFrame
# from pandas import *
df = pd.Series([10,20,30])
print(df)
# Out:
# 1    10
# 4    20
# 3    30
# dtype: int64

# %%
# Dictionary
import pandas as pd
dict = {
        "Name": ["Abhishek","dheeraj","abhishek","parveen","aarav"],
        "Age": [17,20,20,21,22],
        "salary": [{"in hand": "15000","ctc": "1.21LPA"},
                   {"in hand": "16000","ctc": "1.5lpa"},
                   {"in hand": "16000","ctc":"1.55lpa"},
                   {"in hand": "17000","ctc": "1.8lpa"},
                   {"in hand": "18000","ctc": "1.9lpa"}
                   ]
        }
df = pd.DataFrame(dict)
print(df)
# Out:
# [['Abhishek' 17 {'in hand': '15000', 'ctc': '1.21LPA'}]
#  ['dheeraj' 20 {'in hand': '16000', 'ctc': '1.5lpa'}]
#  ['abhishek' 20 {'in hand': '16000', 'ctc': '1.55lpa'}]
#  ['parveen' 21 {'in hand': '17000', 'ctc': '1.8lpa'}]
#  ['aarav' 22 {'in hand': '18000', 'ctc': '1.9lpa'}]]

# %%
# csv
import pandas as pd
# method of github
# url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/file1

# method of direct file upload
# from google.colab import files
# uploaded = files.upload()
# url = "file1.csv"

# method of googledrive
from google.colab import drive
drive.mount('/content/drive')
url = "/content/drive/MyDrive/file1.csv"
df = pd.read_csv(url)
print(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#        name  roll no
# 0   dheeraj      123
# 1     kunal     1234
# 2  abhishek    12345
# 3   praveen    12356
# 4    anjali  1234567

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
url = "/content/drive/MyDrive/file1.json"
df = pd.read_json(url)
print(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#        name  roll no
# 0   dheeraj      123
# 1     kunal     1234
# 2  abhishek    12345
# 3   praveen    12356
# 4    anjali  1234567

# %%
from google.colab import drive
drive.mount('/content/drive')
url = "/content/drive/MyDrive/file1.xlsx"
df = pd.read_excel(url)
df.to_json("file2.json")
print(to_json)
print(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# None
#        name  roll no
# 0   dheeraj      123
# 1     kunal     1234
# 2  abhishek    12345
# 3   praveen    12356
# 4    anjali  1234567
